# %% [markdown]
# <a href="https://colab.research.google.com/github/linhb03/Ai118Project/blob/dev/Prompt_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def generate_question():
    operation = random.choice(['+', '-'])
    if operation == '+':
        a = random.randint(1, 10)
        b = random.randint(1, 10)
        question = f"What is {a} + {b}?"
        answer = a + b
    else:  # subtraction
        a = random.randint(1, 10)
        b = random.randint(1, a)  # ensure no negative answers
        question = f"What is {a} - {b}?"
        answer = a - b
    return question, answer

# Example: Generate 5 random questions
for _ in range(5):
    q, a = generate_question()
    print(q, "Answer:", a)
# Out:
# What is 1 - 1? Answer: 0
# What is 8 - 6? Answer: 2
# What is 1 + 6? Answer: 7
# What is 10 - 3? Answer: 7
# What is 8 + 7? Answer: 15
